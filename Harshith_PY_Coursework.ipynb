# %%
from pickle import UnpicklingError
import pandas as pd;
import numpy as np;
import matplotlib as plt;
# %matplotlib inline
import seaborn as sns;
Data= pd.read_csv("/Student_performance_data _.csv")
print("The number of entries in the files are: "+str(len(Data.index)))
Data.head(5)
# Out:
# The number of entries in the files are: 2392
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# ...

# %% [markdown]
# Checking for Null Values

# %%
Data.isnull()
# Out:
#       StudentID    Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0         False  False   False      False              False            False
# 1         False  False   False      False              False            False
# 2         False  False   False      False              False            False
# 3         False  False   False      False              False            False
# 4         False  False   False      False              False            False
# ...         ...    ...     ...        ...                ...              ...
# 2387      False  False   False      False              False            False
# 2388      False  False   False      False              False            False
# 2389      False  False   False      False              False            False
# 2390      False  False   False      False              False            False
# 2391      False  False   False      False              False            False
#
# ...

# %%
Data.isnull().sum()
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
sns.heatmap(Data.isnull()) #Heatmap displaying for null values if any
# Out:
# <Axes: >

# %% [markdown]
# Plots to show correlation between colums which are directly or indirectly affecting

# %%
sns.countplot(x="Tutoring",hue="GradeClass",data=Data)
# Out:
# <Axes: xlabel='Tutoring', ylabel='count'>

# %%
Data.plot.hist('ParentalEducation')
# Out:
# array([<Axes: title={'center': '0'}, ylabel='Frequency'>,
#        <Axes: title={'center': '1'}, ylabel='Frequency'>,
#        <Axes: title={'center': '2'}, ylabel='Frequency'>,
#        <Axes: title={'center': '3'}, ylabel='Frequency'>,
#        <Axes: title={'center': '4'}, ylabel='Frequency'>], dtype=object)

# %%
sns.countplot(x='ParentalSupport',hue='GPA',data=Data)
# Out:
# <Axes: xlabel='ParentalSupport', ylabel='count'>

# %%
Grade= pd.DataFrame(data=Data, columns=['GradeClass', 'StudentID'])
Grade.groupby('GradeClass').count().plot(kind='pie', legend=False, subplots=True, autopct='%.0f%%')#,labels=['ReturningVisitor', 'NewVisitor', 'Other'])
# Out:
# array([<Axes: ylabel='StudentID'>], dtype=object)

# %%
sns.histplot(data=Data, x="StudyTimeWeekly", hue="GradeClass", multiple="stack")
# Out:
# <Axes: xlabel='StudyTimeWeekly', ylabel='Count'>

# %%
sns.histplot(data=Data, x="Absences", hue="GradeClass", multiple="stack")
# Out:
# <Axes: xlabel='Absences', ylabel='Count'>

# %%
sns.kdeplot(data=Data, x="ParentalSupport", hue="GradeClass", multiple="stack")
# Out:
# <Axes: xlabel='ParentalSupport', ylabel='Density'>

# %% [markdown]
# From the above plots and pie charts we can obtain the major relation between gradeclass and other factors affecting it.
# Further for future scope we can include data preprocessing, test and train the data set for model implementation and performance evaluation using classifiers.
